# %%
# Home Appliances Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Dataset
df = pd.read_csv('../data/home_data.csv')

# %%
df_devices = df.groupby(['from_time', 'device', 'type']).mean()['power']
# df_devices = df_devices.reset_index()
df_devices.to_dict()

tup = ('00:00:00', 'AC', 'indoor')
dd = {}
dd[tup[0]] = {tup[1]: {tup[2]: {}}}
dd
# Out:
# {'00:00:00': {'AC': {'indoor': {}}}}

# %%
df_devices
# Out:
#     from_time         device     type        power
# 0    00:00:00             AC   indoor  1362.214286
# 1    00:00:00             AC  outdoor  3470.705882
# 2    00:00:00       Computer   indoor   399.000000
# 3    00:00:00       Computer  outdoor   412.400000
# 4    00:00:00         Heater   indoor  2258.375000
# 5    00:00:00         Heater  outdoor  2274.666667
# 6    00:00:00         Lights   indoor  1535.000000
# 7    00:00:00         Lights  outdoor  3475.473684
# 8    00:00:00      Microwave   indoor  1420.000000
# 9    00:00:00      Microwave  outdoor  1489.933333
# 10   00:00:00  Refridgerator   indoor   192.388889
# 11   00:00:00  Refridgerator  outdoor   195.076923
# 12   00:00:00     Television   indoor   243.666667
# 13   00:00:00     Television  outdoor   261.500000
# 14   01:00:00             AC   indoor  1493.071429
# 15   01:00:00             AC  outdoor  3724.352941
# 16   01:00:00       Computer   indoor   416.461538
# ...

# %%
df_temp = df[['from_time','device', 'type' , 'power']]

target_series = pd.Series()

df_temp.head()
# Out:
#   from_time    device    type  power
# 0  04:00:00        AC  indoor   1363
# 1  08:00:00  Computer  indoor    487
# 2  05:00:00  Computer  indoor    464
# 3  01:00:00  Computer  indoor    389
# 4  08:00:00  Computer  indoor    338

# %%
d = {'04:00:00': {'AC': {'indoor': 1363}}}
d[df_temp['from_time'][0]][df_temp['device'][0]][df_temp['type'][0]]
# Out:
# 1363
