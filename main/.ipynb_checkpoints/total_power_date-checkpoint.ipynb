# %%
# Home Appliances Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Dataset
df = pd.read_csv('../data/home_data.csv')

# %%
df.head()
# Out:
#      device  building  floor   room    type  power        date from_time  \
# 0        AC         1      1  101.0  indoor   1363  2018-01-01  04:00:00
# 1  Computer         1      1  101.0  indoor    487  2018-01-27  08:00:00
# 2  Computer         1      1  101.0  indoor    464  2018-01-29  05:00:00
# 3  Computer         1      1  101.0  indoor    389  2018-01-30  01:00:00
# 4  Computer         1      1  101.0  indoor    338  2018-01-30  08:00:00
#
#     to_time  no_of_people  time_stayed_mins
# 0  05:00:00             9                 7
# 1  09:00:00             0                17
# 2  06:00:00             1                16
# 3  02:00:00             8                27
# 4  09:00:00             2                 4

# %%
# Total Power Consumption on dates
df_date_group = df.groupby(['date', 'from_time', 'to_time', 'device', 'type', 'no_of_people']).sum()['power']
df_date_group
# Out:
# date        from_time  to_time   device    type     no_of_people
# 2018-01-01  00:00:00   01:00:00  AC        indoor   2               1568
#                                                     5               1305
#                                                     7               1439
#                                                     8               1360
#                                                     10              1161
#                                            outdoor  2               3109
#                                                     7               2531
#             01:00:00   02:00:00  AC        indoor   6               1416
#                                            outdoor  1               4192
#                                                     4               9021
#                                                     6               4487
#                                                     8               2103
# ...
