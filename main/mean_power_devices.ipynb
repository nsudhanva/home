# %%
# Home Appliances Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast

# %%
# Import Dataset
df = pd.read_csv('../data/home_data.csv')

# %%
df_devices = df.groupby(['from_time', 'device', 'type']).mean()['power']
df_devices.reset_index()
df_devices
# Out:
# from_time  device         type
# 00:00:00   AC             indoor     1362.214286
#                           outdoor    3470.705882
#            Computer       indoor      399.000000
#                           outdoor     412.400000
#            Heater         indoor     2258.375000
#                           outdoor    2274.666667
#            Lights         indoor     1535.000000
#                           outdoor    3475.473684
#            Microwave      indoor     1420.000000
#                           outdoor    1489.933333
#            Refridgerator  indoor      192.388889
#                           outdoor     195.076923
#            Television     indoor      243.666667
#                           outdoor     261.500000
# 01:00:00   AC             indoor     1493.071429
#                           outdoor    3724.352941
#            Computer       indoor      416.461538
#                           outdoor     413.555556
#            Heater         indoor     2143.277778
#                           outdoor    2286.461538
#            Lights         indoor     1447.950000
#                           outdoor    3092.454545
#            Microwave      indoor     1536.857143
#                           outdoor    1429.294118
#            Refridgerator  indoor      207.416667
#                           outdoor     234.684211
#            Television     indoor      251.000000
#                           outdoor     249.904762
# 02:00:00   AC             indoor     1435.846154
#                           outdoor    3413.000000
#                                         ...
# 21:00:00   Television     indoor      254.727273
#                           outdoor     248.350000
# 22:00:00   AC             indoor     1411.444444
#                           outdoor    3791.153846
#            Computer       indoor      404.400000
#                           outdoor     432.181818
#            Heater         indoor     2280.642857
#                           outdoor    2243.470588
#            Lights         indoor     1364.333333
#                           outdoor    3389.562500
#            Microwave      indoor     1436.052632
#                           outdoor    1463.000000
#            Refridgerator  indoor      181.090909
#                           outdoor     190.650000
#            Television     indoor      241.733333
#                           outdoor     258.312500
# 23:00:00   AC             indoor     1503.764706
#                           outdoor    3403.857143
#            Computer       indoor      393.071429
#                           outdoor     404.764706
#            Heater         indoor     2306.523810
#                           outdoor    2382.800000
#            Lights         indoor     1466.352941
#                           outdoor    3654.714286
#            Microwave      indoor     1584.200000
#                           outdoor    1612.062500
#            Refridgerator  indoor      188.315789
#                           outdoor     210.500000
#            Television     indoor      242.785714
#                           outdoor     249.764706
# Name: power, Length: 336, dtype: float64

# %%
df_devices
# Out:
#                                        power
# from_time device        type
# 00:00:00  AC            indoor   1362.214286
#                         outdoor  3470.705882
#           Computer      indoor    399.000000
#                         outdoor   412.400000
#           Heater        indoor   2258.375000
#                         outdoor  2274.666667
#           Lights        indoor   1535.000000
#                         outdoor  3475.473684
#           Microwave     indoor   1420.000000
#                         outdoor  1489.933333
#           Refridgerator indoor    192.388889
#                         outdoor   195.076923
#           Television    indoor    243.666667
#                         outdoor   261.500000
# 01:00:00  AC            indoor   1493.071429
#                         outdoor  3724.352941
#           Computer      indoor    416.461538
#                         outdoor   413.555556
#           Heater        indoor   2143.277778
#                         outdoor  2286.461538
#           Lights        indoor   1447.950000
#                         outdoor  3092.454545
#           Microwave     indoor   1536.857143
#                         outdoor  1429.294118
#           Refridgerator indoor    207.416667
#                         outdoor   234.684211
#           Television    indoor    251.000000
#                         outdoor   249.904762
# 02:00:00  AC            indoor   1435.846154
#                         outdoor  3413.000000
# ...                                      ...
# 21:00:00  Television    indoor    254.727273
#                         outdoor   248.350000
# 22:00:00  AC            indoor   1411.444444
#                         outdoor  3791.153846
#           Computer      indoor    404.400000
#                         outdoor   432.181818
#           Heater        indoor   2280.642857
#                         outdoor  2243.470588
#           Lights        indoor   1364.333333
#                         outdoor  3389.562500
#           Microwave     indoor   1436.052632
#                         outdoor  1463.000000
#           Refridgerator indoor    181.090909
#                         outdoor   190.650000
#           Television    indoor    241.733333
#                         outdoor   258.312500
# 23:00:00  AC            indoor   1503.764706
#                         outdoor  3403.857143
#           Computer      indoor    393.071429
#                         outdoor   404.764706
#           Heater        indoor   2306.523810
#                         outdoor  2382.800000
#           Lights        indoor   1466.352941
#                         outdoor  3654.714286
#           Microwave     indoor   1584.200000
#                         outdoor  1612.062500
#           Refridgerator indoor    188.315789
#                         outdoor   210.500000
#           Television    indoor    242.785714
#                         outdoor   249.764706
#
# [336 rows x 1 columns]
