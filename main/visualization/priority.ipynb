# %% [markdown]
# # Applying Machine Learning and Deep Learning to identify home appliances consuming excess power
#
# ## Copyright (c) 2018, Faststream Technologies
# ## Author: Sudhanva Narayana

# %%
# Home Appliances Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Dataset
df = pd.read_excel('../../data/home.xlsx', sheet_name='Sheet3')

# %%
df.head()
# Out:
#   device weather_type           time  priority  order  out
# 0     AC     low cold  early morning         8     52    0
# 1     AC     low cold        morning         8     49    0
# 2     AC     low cold      afternoon         8     48    0
# 3     AC     low cold        evening         8     50    0
# 4     AC     low cold          night         8     51    0

# %%
df_group = df.groupby(['device', 'weather_type', 'time', 'priority', 'order']).size().to_frame()

# %%
# Out:
# {('AC',
#   'cold',
#   'afternoon',
#   11,
#   66):   device weather_type       time  priority  order  out
#  8     AC         cold  afternoon        11     66    0,
#  ('AC',
#   'cold',
#   'early morning',
#   11,
#   70):   device weather_type           time  priority  order  out
#  6     AC         cold  early morning        11     70    0,
#  ('AC',
#   'cold',
#   'evening',
#   11,
#   68):   device weather_type     time  priority  order  out
#  9     AC         cold  evening        11     68    0,
#  ('AC',
#   'cold',
#   'midnight',
#   11,
#   71):    device weather_type      time  priority  order  out
#  11     AC         cold  midnight        11     71    0,
#  ('AC',
#   'cold',
#   'morning',
#   11,
#   67):   device weather_type     time  priority  order  out
#  7     AC         cold  morning        11     67    0,
#  ('AC',
#   'cold',
#   'night',
#   11,
#   69):    device weather_type   time  priority  order  out
#  10     AC         cold  night        11     69    0,
#  ('AC',
#   'hot',
#   'afternoon',
#   4,
#   25):    device weather_type       time  priority  order  out
#  26     AC          hot  afternoon         4     25    0,
#  ('AC',
#   'hot',
#   'early morning',
#   4,
#   29):    device weather_type           time  priority  order  out
#  24     AC          hot  early morning         4     29    0,
#  ('AC',
#   'hot',
#   'evening',
#   4,
#   27):    device weather_type     time  priority  order  out
#  27     AC          hot  evening         4     27    0,
#  ('AC',
#   'hot',
#   'midnight',
#   4,
#   30):    device weather_type      time  priority  order  out
#  29     AC          hot  midnight         4     30    0,
#  ('AC',
#   'hot',
#   'morning',
#   4,
#   26):    device weather_type     time  priority  order  out
#  25     AC          hot  morning         4     26    0,
#  ('AC',
#   'hot',
#   'night',
#   4,
#   28):    device weather_type   time  priority  order  out
#  28     AC          hot  night         4     28    0,
#  ('AC',
#   'low cold',
#   'afternoon',
#   8,
#   48):   device weather_type       time  priority  order  out
#  2     AC     low cold  afternoon         8     48    0,
#  ('AC',
#   'low cold',
#   'early morning',
#   8,
#   52):   device weather_type           time  priority  order  out
#  0     AC     low cold  early morning         8     52    0,
#  ('AC',
#   'low cold',
#   'evening',
#   8,
#   50):   device weather_type     time  priority  order  out
#  3     AC     low cold  evening         8     50    0,
#  ('AC',
#   'low cold',
#   'midnight',
#   8,
#   53):   device weather_type      time  priority  order  out
#  5     AC     low cold  midnight         8     53    0,
#  ('AC',
#   'low cold',
#   'morning',
#   8,
#   49):   device weather_type     time  priority  order  out
#  1     AC     low cold  morning         8     49    0,
#  ('AC',
#   'low cold',
#   'night',
#   8,
#   51):   device weather_type   time  priority  order  out
#  4     AC     low cold  night         8     51    0,
#  ('AC',
#   'low hot',
#   'afternoon',
#   6,
#   37):    device weather_type       time  priority  order  out
#  20     AC      low hot  afternoon         6     37    0,
#  ('AC',
#   'low hot',
#   'early morning',
#   6,
#   41):    device weather_type           time  priority  order  out
#  18     AC      low hot  early morning         6     41    0,
#  ('AC',
#   'low hot',
#   'evening',
#   6,
#   39):    device weather_type     time  priority  order  out
#  21     AC      low hot  evening         6     39    0,
#  ('AC',
#   'low hot',
#   'midnight',
#   6,
#   42):    device weather_type      time  priority  order  out
#  23     AC      low hot  midnight         6     42    0,
#  ('AC',
#   'low hot',
#   'morning',
#   6,
#   38):    device weather_type     time  priority  order  out
#  19     AC      low hot  morning         6     38    0,
#  ('AC',
#   'low hot',
#   'night',
#   6,
#   40):    device weather_type   time  priority  order  out
#  22     AC      low hot  night         6     40    0,
#  ('AC',
#   'very cold',
#   'afternoon',
#   16,
#   96):    device weather_type       time  priority  order  out
#  14     AC    very cold  afternoon        16     96    0,
#  ('AC',
#   'very cold',
#   'early morning',
#   16,
#   100):    device weather_type           time  priority  order  out
#  12     AC    very cold  early morning        16    100    0,
#  ('AC',
#   'very cold',
#   'evening',
#   16,
#   98):    device weather_type     time  priority  order  out
#  15     AC    very cold  evening        16     98    0,
#  ('AC',
#   'very cold',
#   'midnight',
#   16,
#   101):    device weather_type      time  priority  order  out
#  17     AC    very cold  midnight        16    101    0,
#  ('AC',
#   'very cold',
#   'morning',
#   16,
#   97):    device weather_type     time  priority  order  out
#  13     AC    very cold  morning        16     97    0,
#  ('AC',
#   'very cold',
#   'night',
#   16,
#   99):    device weather_type   time  priority  order  out
#  16     AC    very cold  night        16     99    0,
#  ('AC',
#   'very hot',
#   'afternoon',
#   2,
#   13):    device weather_type       time  priority  order  out
#  32     AC     very hot  afternoon         2     13    0,
#  ('AC',
#   'very hot',
#   'early morning',
#   2,
#   17):    device weather_type           time  priority  order  out
#  30     AC     very hot  early morning         2     17    0,
#  ('AC',
#   'very hot',
#   'evening',
#   2,
#   15):    device weather_type     time  priority  order  out
#  33     AC     very hot  evening         2     15    0,
#  ('AC',
#   'very hot',
#   'midnight',
#   2,
#   18):    device weather_type      time  priority  order  out
#  35     AC     very hot  midnight         2     18    0,
#  ('AC',
#   'very hot',
#   'morning',
#   2,
#   14):    device weather_type     time  priority  order  out
#  31     AC     very hot  morning         2     14    0,
#  ('AC',
#   'very hot',
#   'night',
#   2,
#   16):    device weather_type   time  priority  order  out
#  34     AC     very hot  night         2     16    0,
#  ('Heater',
#   'cold',
#   'afternoon',
#   5,
#   33):     device weather_type       time  priority  order  out
#  44  Heater         cold  afternoon         5     33    0,
#  ('Heater',
#   'cold',
#   'early morning',
#   5,
#   31):     device weather_type           time  priority  order  out
#  42  Heater         cold  early morning         5     31    0,
#  ('Heater',
#   'cold',
#   'evening',
#   5,
#   34):     device weather_type     time  priority  order  out
#  45  Heater         cold  evening         5     34    0,
#  ('Heater',
#   'cold',
#   'midnight',
#   5,
#   36):     device weather_type      time  priority  order  out
#  47  Heater         cold  midnight         5     36    0,
#  ('Heater',
#   'cold',
#   'morning',
#   5,
#   32):     device weather_type     time  priority  order  out
#  43  Heater         cold  morning         5     32    0,
#  ('Heater',
#   'cold',
#   'night',
#   5,
#   35):     device weather_type   time  priority  order  out
#  46  Heater         cold  night         5     35    0,
#  ('Heater',
#   'hot',
#   'afternoon',
#   12,
#   74):     device weather_type       time  priority  order  out
#  62  Heater          hot  afternoon        12     74    0,
#  ('Heater',
#   'hot',
#   'early morning',
#   12,
#   72):     device weather_type           time  priority  order  out
#  60  Heater          hot  early morning        12     72    0,
#  ('Heater',
#   'hot',
#   'evening',
#   12,
#   75):     device weather_type     time  priority  order  out
#  63  Heater          hot  evening        12     75    0,
#  ('Heater',
#   'hot',
#   'midnight',
#   12,
#   77):     device weather_type      time  priority  order  out
#  65  Heater          hot  midnight        12     77    0,
#  ('Heater',
#   'hot',
#   'morning',
#   12,
#   73):     device weather_type     time  priority  order  out
#  61  Heater          hot  morning        12     73    0,
#  ('Heater',
#   'hot',
#   'night',
#   12,
#   76):     device weather_type   time  priority  order  out
#  64  Heater          hot  night        12     76    0,
#  ('Heater',
#   'low cold',
#   'afternoon',
#   7,
#   44):     device weather_type       time  priority  order  out
#  38  Heater     low cold  afternoon         7     44    0,
#  ('Heater',
#   'low cold',
#   'early morning',
#   7,
#   42):     device weather_type           time  priority  order  out
#  36  Heater     low cold  early morning         7     42    0,
#  ('Heater',
#   'low cold',
#   'evening',
#   7,
#   45):     device weather_type     time  priority  order  out
#  39  Heater     low cold  evening         7     45    0,
#  ('Heater',
#   'low cold',
#   'midnight',
#   7,
#   47):     device weather_type      time  priority  order  out
#  41  Heater     low cold  midnight         7     47    0,
#  ('Heater',
#   'low cold',
#   'morning',
#   7,
#   43):     device weather_type     time  priority  order  out
#  37  Heater     low cold  morning         7     43    0,
#  ('Heater',
#   'low cold',
#   'night',
#   7,
#   46):     device weather_type   time  priority  order  out
#  40  Heater     low cold  night         7     46    0,
#  ('Heater',
#   'low hot',
#   'afternoon',
#   9,
#   56):     device weather_type       time  priority  order  out
#  56  Heater      low hot  afternoon         9     56    0,
#  ('Heater',
#   'low hot',
#   'early morning',
#   9,
#   54):     device weather_type           time  priority  order  out
#  54  Heater      low hot  early morning         9     54    0,
#  ('Heater',
#   'low hot',
#   'evening',
#   9,
#   57):     device weather_type     time  priority  order  out
#  57  Heater      low hot  evening         9     57    0,
#  ('Heater',
#   'low hot',
#   'midnight',
#   9,
#   59):     device weather_type      time  priority  order  out
#  59  Heater      low hot  midnight         9     59    0,
#  ('Heater',
#   'low hot',
#   'morning',
#   9,
#   55):     device weather_type     time  priority  order  out
#  55  Heater      low hot  morning         9     55    0,
#  ('Heater',
#   'low hot',
#   'night',
#   9,
#   58):     device weather_type   time  priority  order  out
#  58  Heater      low hot  night         9     58    0,
#  ('Heater',
#   'very cold',
#   'afternoon',
#   3,
#   21):     device weather_type       time  priority  order  out
#  50  Heater    very cold  afternoon         3     21    0,
#  ('Heater',
#   'very cold',
#   'early morning',
#   3,
#   19):     device weather_type           time  priority  order  out
#  48  Heater    very cold  early morning         3     19    0,
#  ('Heater',
#   'very cold',
#   'evening',
#   3,
#   22):     device weather_type     time  priority  order  out
#  51  Heater    very cold  evening         3     22    0,
#  ('Heater',
#   'very cold',
#   'midnight',
#   3,
#   24):     device weather_type      time  priority  order  out
#  53  Heater    very cold  midnight         3     24    0,
#  ('Heater',
#   'very cold',
#   'morning',
#   3,
#   20):     device weather_type     time  priority  order  out
#  49  Heater    very cold  morning         3     20    0,
#  ('Heater',
#   'very cold',
#   'night',
#   3,
#   23):     device weather_type   time  priority  order  out
#  52  Heater    very cold  night         3     23    0,
#  ('Heater',
#   'very hot',
#   'afternoon',
#   15,
#   92):     device weather_type       time  priority  order  out
#  68  Heater     very hot  afternoon        15     92    0,
#  ('Heater',
#   'very hot',
#   'early morning',
#   15,
#   90):     device weather_type           time  priority  order  out
#  66  Heater     very hot  early morning        15     90    0,
#  ('Heater',
#   'very hot',
#   'evening',
#   15,
#   93):     device weather_type     time  priority  order  out
#  69  Heater     very hot  evening        15     93    0,
#  ('Heater',
#   'very hot',
#   'midnight',
#   15,
#   95):     device weather_type      time  priority  order  out
#  71  Heater     very hot  midnight        15     95    0,
#  ('Heater',
#   'very hot',
#   'morning',
#   15,
#   91):     device weather_type     time  priority  order  out
#  67  Heater     very hot  morning        15     91    0,
#  ('Heater',
#   'very hot',
#   'night',
#   15,
#   94):     device weather_type   time  priority  order  out
#  70  Heater     very hot  night        15     94    0,
#  ('Lights',
#   'cold',
#   'afternoon',
#   17,
#   106):     device weather_type       time  priority  order  out
#  80  Lights         cold  afternoon        17    106    0,
#  ('Lights',
#   'cold',
#   'early morning',
#   10,
#   64):     device weather_type           time  priority  order  out
#  78  Lights         cold  early morning        10     64    0,
#  ('Lights',
#   'cold',
#   'evening',
#   14,
#   88):     device weather_type     time  priority  order  out
#  81  Lights         cold  evening        14     88    0,
#  ('Lights',
#   'cold',
#   'midnight',
#   1,
#   10):     device weather_type      time  priority  order  out
#  83  Lights         cold  midnight         1     10    0,
#  ('Lights',
#   'cold',
#   'morning',
#   13,
#   82):     device weather_type     time  priority  order  out
#  79  Lights         cold  morning        13     82    0,
#  ('Lights',
#   'cold',
#   'night',
#   1,
#   9):     device weather_type   time  priority  order  out
#  82  Lights         cold  night         1      9    0,
#  ('Lights',
#   'hot',
#   'afternoon',
#   17,
#   103):     device weather_type       time  priority  order  out
#  98  Lights          hot  afternoon        17    103    0,
#  ('Lights',
#   'hot',
#   'early morning',
#   10,
#   61):     device weather_type           time  priority  order  out
#  96  Lights          hot  early morning        10     61    0,
#  ('Lights',
#   'hot',
#   'evening',
#   14,
#   85):     device weather_type     time  priority  order  out
#  99  Lights          hot  evening        14     85    0,
#  ('Lights',
#   'hot',
#   'midnight',
#   1,
#   4):      device weather_type      time  priority  order  out
#  101  Lights          hot  midnight         1      4    0,
#  ('Lights',
#   'hot',
#   'morning',
#   13,
#   79):     device weather_type     time  priority  order  out
#  97  Lights          hot  morning        13     79    0,
#  ('Lights',
#   'hot',
#   'night',
#   1,
#   3):      device weather_type   time  priority  order  out
#  100  Lights          hot  night         1      3    0,
#  ('Lights',
#   'low cold',
#   'afternoon',
#   17,
#   107):     device weather_type       time  priority  order  out
#  74  Lights     low cold  afternoon        17    107    0,
#  ('Lights',
#   'low cold',
#   'early morning',
#   10,
#   65):     device weather_type           time  priority  order  out
#  72  Lights     low cold  early morning        10     65    0,
#  ('Lights',
#   'low cold',
#   'evening',
#   14,
#   89):     device weather_type     time  priority  order  out
#  75  Lights     low cold  evening        14     89    0,
#  ('Lights',
#   'low cold',
#   'midnight',
#   1,
#   8):     device weather_type      time  priority  order  out
#  77  Lights     low cold  midnight         1      8    0,
#  ('Lights',
#   'low cold',
#   'morning',
#   13,
#   83):     device weather_type     time  priority  order  out
#  73  Lights     low cold  morning        13     83    0,
#  ('Lights',
#   'low cold',
#   'night',
#   1,
#   7):     device weather_type   time  priority  order  out
#  76  Lights     low cold  night         1      7    0,
#  ('Lights',
#   'low hot',
#   'afternoon',
#   17,
#   104):     device weather_type       time  priority  order  out
#  92  Lights      low hot  afternoon        17    104    0,
#  ('Lights',
#   'low hot',
#   'early morning',
#   10,
#   62):     device weather_type           time  priority  order  out
#  90  Lights      low hot  early morning        10     62    0,
#  ('Lights',
#   'low hot',
#   'evening',
#   14,
#   86):     device weather_type     time  priority  order  out
#  93  Lights      low hot  evening        14     86    0,
#  ('Lights',
#   'low hot',
#   'midnight',
#   1,
#   6):     device weather_type      time  priority  order  out
#  95  Lights      low hot  midnight         1      6    0,
#  ('Lights',
#   'low hot',
#   'morning',
#   13,
#   80):     device weather_type     time  priority  order  out
#  91  Lights      low hot  morning        13     80    0,
#  ('Lights',
#   'low hot',
#   'night',
#   1,
#   5):     device weather_type   time  priority  order  out
#  94  Lights      low hot  night         1      5    0,
#  ('Lights',
#   'very cold',
#   'afternoon',
#   17,
#   105):     device weather_type       time  priority  order  out
#  86  Lights    very cold  afternoon        17    105    0,
#  ('Lights',
#   'very cold',
#   'early morning',
#   10,
#   63):     device weather_type           time  priority  order  out
#  84  Lights    very cold  early morning        10     63    0,
#  ('Lights',
#   'very cold',
#   'evening',
#   14,
#   87):     device weather_type     time  priority  order  out
#  87  Lights    very cold  evening        14     87    0,
#  ('Lights',
#   'very cold',
#   'midnight',
#   1,
#   12):     device weather_type      time  priority  order  out
#  89  Lights    very cold  midnight         1     12    0,
#  ('Lights',
#   'very cold',
#   'morning',
#   13,
#   81):     device weather_type     time  priority  order  out
#  85  Lights    very cold  morning        13     81    0,
#  ('Lights',
#   'very cold',
#   'night',
#   1,
#   11):     device weather_type   time  priority  order  out
#  88  Lights    very cold  night         1     11    0,
#  ('Lights',
#   'very hot',
#   'afternoon',
#   17,
#   102):      device weather_type       time  priority  order  out
#  104  Lights     very hot  afternoon        17    102    0,
#  ('Lights',
#   'very hot',
#   'early morning',
#   10,
#   60):      device weather_type           time  priority  order  out
#  102  Lights     very hot  early morning        10     60    0,
#  ('Lights',
#   'very hot',
#   'evening',
#   14,
#   84):      device weather_type     time  priority  order  out
#  105  Lights     very hot  evening        14     84    0,
#  ('Lights',
#   'very hot',
#   'midnight',
#   1,
#   2):      device weather_type      time  priority  order  out
#  107  Lights     very hot  midnight         1      2    0,
#  ('Lights',
#   'very hot',
#   'morning',
#   13,
#   78):      device weather_type     time  priority  order  out
#  103  Lights     very hot  morning        13     78    0,
#  ('Lights',
#   'very hot',
#   'night',
#   1,
#   1):      device weather_type   time  priority  order  out
#  106  Lights     very hot  night         1      1    0}

# %%
df_group.apply(lambda x:df.)
# Out:
#                                                   0
# device weather_type time          priority order
# AC     cold         afternoon     11       66     1
#                     early morning 11       70     1
#                     evening       11       68     1
#                     midnight      11       71     1
#                     morning       11       67     1
#                     night         11       69     1
#        hot          afternoon     4        25     1
#                     early morning 4        29     1
#                     evening       4        27     1
#                     midnight      4        30     1
#                     morning       4        26     1
#                     night         4        28     1
#        low cold     afternoon     8        48     1
#                     early morning 8        52     1
#                     evening       8        50     1
#                     midnight      8        53     1
#                     morning       8        49     1
#                     night         8        51     1
#        low hot      afternoon     6        37     1
#                     early morning 6        41     1
#                     evening       6        39     1
#                     midnight      6        42     1
#                     morning       6        38     1
#                     night         6        40     1
#        very cold    afternoon     16       96     1
#                     early morning 16       100    1
#                     evening       16       98     1
#                     midnight      16       101    1
#                     morning       16       97     1
#                     night         16       99     1
# ...                                              ..
# Lights hot          afternoon     17       103    1
#                     early morning 10       61     1
#                     evening       14       85     1
#                     midnight      1        4      1
#                     morning       13       79     1
#                     night         1        3      1
#        low cold     afternoon     17       107    1
#                     early morning 10       65     1
#                     evening       14       89     1
#                     midnight      1        8      1
#                     morning       13       83     1
#                     night         1        7      1
#        low hot      afternoon     17       104    1
#                     early morning 10       62     1
#                     evening       14       86     1
#                     midnight      1        6      1
#                     morning       13       80     1
#                     night         1        5      1
#        very cold    afternoon     17       105    1
#                     early morning 10       63     1
#                     evening       14       87     1
#                     midnight      1        12     1
#                     morning       13       81     1
#                     night         1        11     1
#        very hot     afternoon     17       102    1
#                     early morning 10       60     1
#                     evening       14       84     1
#                     midnight      1        2      1
#                     morning       13       78     1
#                     night         1        1      1
#
# [108 rows x 1 columns]
